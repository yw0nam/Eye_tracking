# %%
import pandas as pd
import cv2
import turtle
import numpy as np

# %%
zero_img = np.zeros([1080, 1920, 3])
zero_img_copy = zero_img.copy()
x_axis = np.random.randint(200, 1720, size=(50))
y_axis = np.random.randint(200, 880, size=(50))
data = np.array([x_axis, y_axis])
img = cv2.circle(zero_img_copy, (x_axis[0], y_axis[0]), 40, (0, 255, 0), -1)

# %%
while True :
    cv2.imshow('result', zero_img_copy)

    key = cv2.waitKey(0)
    cv2.destroyAllWindows()
    
    if key == 27 :
        break

# %%
label = pd.DataFrame({'Screen_x': x_axis, 'Screen_y': y_axis})

# %%
label
# Out:
#     Screen_x  Screen_y
# 0        710       775
# 1        533       594
# 2        664       768
# 3        329       498
# 4       1044       638
# 5        905       562
# 6       1803       400
# 7       1484       741
# 8       1028       705
# 9       1709       509
# 10       800       812
# 11       459       194
# 12      1713       794
# 13       713       965
# 14       427       141
# 15       327       807
# 16       919       293
# 17      1190       763
# 18      1128       860
# 19      1049       592
# 20       589       933
# 21       591       641
# 22      1172       501
# 23      1345       712
# 24       828       624
# 25       392       294
# 26      1613       708
# 27       477       556
# 28       515       154
# 29      1107       718
# 30       590       921
# 31      1168       635
# 32       905       949
# 33      1173       535
# 34       191       627
# 35       886       830
# 36       945       345
# 37       762       559
# 38       333       130
# ...
